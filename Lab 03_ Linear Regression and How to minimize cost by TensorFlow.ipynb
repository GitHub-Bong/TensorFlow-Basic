# %% [markdown]
# $$ W:=W-\alpha \frac { 1 }{ m } \sum _{ i=1 }^{ m }{ { (W{ x }^{ i }-y^{ i } })x^{ i } }  $$

# %%
import tensorflow as tf
import numpy as np

X = np.array([1, 2, 3])
Y = np.array([1, 2, 3])

W = tf.Variable(tf.random.normal((1,), -100., 100.))

for step in range(300):
    hypothesis = W * X
    cost = tf.reduce_mean(tf.square(hypothesis - Y))

    alpha = 0.01
    gradient = tf.reduce_mean(tf.multiply(tf.multiply(W, X) - Y, X))
    descent = W - tf.multiply(alpha, gradient)
    W.assign(descent)
    
    if step % 10 == 0:
        print('{:5} | {:10.4f} | {:10.6f}'.format(
            step, cost.numpy(), W.numpy()[0]))
# Out:
#     0 |  6572.7681 |  36.777958
#    10 |  2527.2251 |  23.185200
#    20 |   971.7165 |  14.756602
#    30 |   373.6244 |   9.530196
#    40 |   143.6584 |   6.289405
#    50 |    55.2365 |   4.279855
#    60 |    21.2384 |   3.033773
#    70 |     8.1662 |   2.261102
#    80 |     3.1399 |   1.781984
#    90 |     1.2073 |   1.484893
#   100 |     0.4642 |   1.300673
#   110 |     0.1785 |   1.186441
#   120 |     0.0686 |   1.115608
#   130 |     0.0264 |   1.071686
#   140 |     0.0101 |   1.044451
#   150 |     0.0039 |   1.027563
#   160 |     0.0015 |   1.017091
#   170 |     0.0006 |   1.010598
#   180 |     0.0002 |   1.006572
#   190 |     0.0001 |   1.004075
#   200 |     0.0000 |   1.002527
#   210 |     0.0000 |   1.001567
#   220 |     0.0000 |   1.000972
#   230 |     0.0000 |   1.000602
#   240 |     0.0000 |   1.000374
#   250 |     0.0000 |   1.000232
#   260 |     0.0000 |   1.000144
#   270 |     0.0000 |   1.000089
#   280 |     0.0000 |   1.000055
#   290 |     0.0000 |   1.000034
