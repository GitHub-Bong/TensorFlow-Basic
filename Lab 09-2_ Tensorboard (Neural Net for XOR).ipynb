# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

x_data = [[0, 0],
          [0, 1],
          [1, 0],
          [1, 1]]
y_data = [[0],
          [1],
          [1],
          [0]]

model = tf.keras.models.Sequential([
          tf.keras.layers.Dense(10, input_dim=2, activation=tf.nn.sigmoid),
          tf.keras.layers.Dense(10, activation=tf.nn.sigmoid),
          tf.keras.layers.Dense(10, activation=tf.nn.sigmoid),
          tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])
tb_hist = tf.keras.callbacks.TensorBoard(log_dir='./logs/xor_logs_r0_01', histogram_freq=0, write_graph=True,
                                         write_images=True)
model.fit(x_data, y_data, epochs=50, callbacks=[tb_hist])

model.predict_classes(x_data)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 452ms/step - loss: 0.7638 - binary_accuracy: 0.5000
# Epoch 2/50
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7613 - binary_accuracy: 0.5000
# Epoch 3/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7588 - binary_accuracy: 0.5000
# Epoch 4/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7563 - binary_accuracy: 0.5000
# Epoch 5/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7539 - binary_accuracy: 0.5000
# Epoch 6/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7516 - binary_accuracy: 0.5000
# Epoch 7/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7493 - binary_accuracy: 0.5000
# Epoch 8/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7470 - binary_accuracy: 0.5000
# Epoch 9/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7449 - binary_accuracy: 0.5000
# Epoch 10/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7427 - binary_accuracy: 0.5000
# Epoch 11/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7406 - binary_accuracy: 0.5000
# Epoch 12/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7386 - binary_accuracy: 0.5000
# Epoch 13/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7366 - binary_accuracy: 0.5000
# Epoch 14/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7347 - binary_accuracy: 0.5000
# Epoch 15/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7328 - binary_accuracy: 0.5000
# Epoch 16/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7310 - binary_accuracy: 0.5000
# Epoch 17/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7292 - binary_accuracy: 0.5000
# Epoch 18/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7275 - binary_accuracy: 0.5000
# Epoch 19/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7258 - binary_accuracy: 0.5000
# Epoch 20/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7242 - binary_accuracy: 0.5000
# Epoch 21/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7227 - binary_accuracy: 0.5000
# Epoch 22/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7212 - binary_accuracy: 0.5000
# Epoch 23/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7197 - binary_accuracy: 0.5000
# Epoch 24/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7183 - binary_accuracy: 0.5000
# Epoch 25/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7170 - binary_accuracy: 0.5000
# Epoch 26/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7157 - binary_accuracy: 0.5000
# Epoch 27/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7145 - binary_accuracy: 0.5000
# Epoch 28/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7133 - binary_accuracy: 0.5000
# Epoch 29/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7121 - binary_accuracy: 0.5000
# Epoch 30/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7110 - binary_accuracy: 0.5000
# Epoch 31/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7100 - binary_accuracy: 0.5000
# Epoch 32/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7090 - binary_accuracy: 0.5000
# Epoch 33/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7080 - binary_accuracy: 0.5000
# Epoch 34/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7071 - binary_accuracy: 0.5000
# Epoch 35/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7062 - binary_accuracy: 0.5000
# Epoch 36/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7054 - binary_accuracy: 0.5000
# Epoch 37/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7046 - binary_accuracy: 0.5000
# Epoch 38/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7038 - binary_accuracy: 0.5000
# Epoch 39/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7031 - binary_accuracy: 0.5000
# Epoch 40/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7025 - binary_accuracy: 0.5000
# Epoch 41/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7018 - binary_accuracy: 0.5000
# Epoch 42/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7012 - binary_accuracy: 0.5000
# Epoch 43/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7006 - binary_accuracy: 0.5000
# Epoch 44/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7001 - binary_accuracy: 0.5000
# Epoch 45/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6996 - binary_accuracy: 0.5000
# Epoch 46/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6991 - binary_accuracy: 0.5000
# Epoch 47/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6987 - binary_accuracy: 0.5000
# Epoch 48/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6982 - binary_accuracy: 0.5000
# Epoch 49/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6978 - binary_accuracy: 0.5000
# Epoch 50/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6975 - binary_accuracy: 0.5000
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([[0],
#        [0],
#        [0],
#        [0]], dtype=int32)
